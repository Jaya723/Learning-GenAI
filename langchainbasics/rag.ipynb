# %% [markdown]
# DATA INGESTION PIPELINE

# %%
##document structure
from langchain_core.documents import Document

# %%
doc=Document(page_content="this is the main text content of the document to create a RAG system", 
             metadata={#used for applying the filters to the document using the metadata field
                 "source": "example.txt",
                 "pages": 1,
                 "author":"Jaya Agarwal",
                 "date_created":"2026-04-25"
             })
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Jaya Agarwal', 'date_created': '2026-04-25'}, page_content='this is the main text content of the document to create a RAG system')

# %%
sample_texts={
    "../data/text_files/python_intro.txt":""" 
Python Programming Basics

Python is a high-level, interpreted programming language known for its simplicity and readability. It is widely used in web development, data science, artificial intelligence, and automation.

Python Variables and Data Types

Variables in Python are used to store data values. Python does not require explicit declaration of variable type.

Common data types include:

* int: Integer values (e.g., 10, 20)
* float: Decimal values (e.g., 10.5, 3.14)
* str: String values (e.g., "hello")
* bool: Boolean values (True or False)

Python Control Structures

Control structures manage the flow of execution in a program.

1. Conditional Statements:

* if statement
* if-else statement
* if-elif-else ladder

Example:
if x > 10:
print("Greater than 10")
else:
print("Less or equal to 10")

2. Loops:

* for loop: iterates over a sequence
* while loop: runs while condition is true

Python Functions

Functions are reusable blocks of code defined using the 'def' keyword.

Example:
def add(a, b):
return a + b

Functions help in modular programming and code reusability.

Python Lists

Lists are ordered, mutable collections.

Example:
my_list = [1, 2, 3, 4]

Common operations:

* append()
* remove()
* sort()

Python Dictionaries

Dictionaries store key-value pairs.

Example:
student = {"name": "John", "age": 20}

They allow fast lookup using keys.

Python for Data Science

Python is widely used in data science with libraries such as:

* NumPy for numerical computing
* Pandas for data analysis
* Matplotlib for visualization

Python in Machine Learning

Python supports machine learning using libraries like:

* Scikit-learn
* TensorFlow
* PyTorch

These libraries help build predictive models and neural networks.

Conclusion

Python is a versatile and powerful programming language used across multiple domains including web development, automation, artificial intelligence, and data science.

""",

"../data/text_files/machine_learning.txt":"""
Machine Learning Basics

Machine Learning is a subset of Artificial Intelligence that enables systems to learn patterns from data and make decisions without being explicitly programmed. It focuses on building models that improve their performance with experience.

Types of Machine Learning

1. Supervised Learning:
   Supervised learning uses labeled data to train models. The input data is paired with the correct output.

Examples:

* Classification (e.g., spam detection)
* Regression (e.g., predicting house prices)

Common algorithms:

* Linear Regression
* Logistic Regression
* Decision Trees
* Support Vector Machines

2. Unsupervised Learning:
   Unsupervised learning works with unlabeled data and finds hidden patterns.

Examples:

* Clustering (e.g., customer segmentation)
* Dimensionality Reduction

Common algorithms:

* K-Means Clustering
* Hierarchical Clustering
* Principal Component Analysis (PCA)

3. Reinforcement Learning:
   Reinforcement learning involves an agent that learns by interacting with an environment using rewards and penalties.

Key concepts:

* Agent
* Environment
* Reward
* Policy

Machine Learning Workflow

1. Data Collection:
   Gather relevant data from various sources.

2. Data Preprocessing:
   Clean and prepare data by handling missing values, normalization, and encoding categorical variables.

3. Feature Engineering:
   Select and transform important features that improve model performance.

4. Model Selection:
   Choose an appropriate algorithm based on the problem type.

5. Model Training:
   Train the model using training data.

6. Model Evaluation:
   Evaluate performance using metrics like accuracy, precision, recall, and F1-score.

7. Deployment:
   Deploy the model in a real-world application.

Overfitting and Underfitting

Overfitting occurs when a model learns noise from training data and performs poorly on new data.

Underfitting occurs when a model is too simple and fails to capture patterns.

Solutions:

* Cross-validation
* Regularization
* More data

Evaluation Metrics

For Classification:

* Accuracy
* Precision
* Recall
* F1-score

For Regression:

* Mean Squared Error (MSE)
* Mean Absolute Error (MAE)
* R-squared

Popular Machine Learning Libraries in Python

* Scikit-learn: General-purpose ML library
* TensorFlow: Deep learning framework
* PyTorch: Flexible deep learning library

Applications of Machine Learning

* Image Recognition
* Natural Language Processing
* Recommendation Systems
* Fraud Detection
* Autonomous Vehicles

Conclusion

Machine Learning is a powerful tool that enables systems to learn from data and make intelligent decisions. It is widely used across industries such as healthcare, finance, e-commerce, and automation.

"""
}

for filepath,text in sample_texts.items():
    with open(filepath,"w") as f:
        f.write(text)
print("sample text files created")
# Out:
# sample text files created

# %%
###Text Loader
from langchain_community.document_loaders import TextLoader
loader=TextLoader("../data/text_files/python_intro.txt",encoding='utf-8')
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content=' \nPython Programming Basics\n\nPython is a high-level, interpreted programming language known for its simplicity and readability. It is widely used in web development, data science, artificial intelligence, and automation.\n\nPython Variables and Data Types\n\nVariables in Python are used to store data values. Python does not require explicit declaration of variable type.\n\nCommon data types include:\n\n* int: Integer values (e.g., 10, 20)\n* float: Decimal values (e.g., 10.5, 3.14)\n* str: String values (e.g., "hello")\n* bool: Boolean values (True or False)\n\nPython Control Structures\n\nControl structures manage the flow of execution in a program.\n\n1. Conditional Statements:\n\n* if statement\n* if-else statement\n* if-elif-else ladder\n\nExample:\nif x > 10:\nprint("Greater than 10")\nelse:\nprint("Less or equal to 10")\n\n2. Loops:\n\n* for loop: iterates over a sequence\n* while loop: runs 
# ...

# %%
###Directory loader(Reading all the files from the directory)
from langchain_community.document_loaders import DirectoryLoader
dir_loader=DirectoryLoader("../data/text_files",
                           glob="**/*.txt", #pattern to match
                           loader_cls=TextLoader,
                           loader_kwargs={'encoding':'utf-8'},
                           show_progress=False
                           )

documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='\nMachine Learning Basics\n\nMachine Learning is a subset of Artificial Intelligence that enables systems to learn patterns from data and make decisions without being explicitly programmed. It focuses on building models that improve their performance with experience.\n\nTypes of Machine Learning\n\n1. Supervised Learning:\n   Supervised learning uses labeled data to train models. The input data is paired with the correct output.\n\nExamples:\n\n* Classification (e.g., spam detection)\n* Regression (e.g., predicting house prices)\n\nCommon algorithms:\n\n* Linear Regression\n* Logistic Regression\n* Decision Trees\n* Support Vector Machines\n\n2. Unsupervised Learning:\n   Unsupervised learning works with unlabeled data and finds hidden patterns.\n\nExamples:\n\n* Clustering (e.g., customer segmentation)\n* Dimensionality Reduction\n\nCommon algorithms:\n\n* K-Means Clustering\n* Hierarchical Cl
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader
dir_loader=DirectoryLoader("../data/pdf",
                           glob="**/*.pdf",
                           loader_cls=PyMuPDFLoader,
                           show_progress=False
                           )
document=dir_loader.load()
document
# Out:
# [Document(metadata={'producer': 'Adobe Scan for Android 23.12.15-google-dynamic', 'creator': 'Adobe Scan for Android 23.12.15-google-dynamic', 'creationdate': '', 'source': '..\\data\\pdf\\6.POS.pdf', 'file_path': '..\\data\\pdf\\6.POS.pdf', 'total_pages': 11, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0}, page_content='2 \ntu \nPuoblem \ntags \ni \ne aing det is the Dnl \nin \ne \namhigueus \nStochaatic Pos tagg \nPaob. \nNO \nDOMS \nMeaauumet \nenelntesd mat \nquety \nDate \nWa \nwy \nmay \nyield inadmisi ble den,-9 \nThe b.est tag toa gen \nLad is dellmimol \ny \ne pobabi lty tat \nw hekune \nSo, \nLoil \ndooe \nPage No. \nioleity Pos tag \nAulineed \nto ioliity \nweros tag \nsCCUing \nIwauis tainy epus \npAewius tags \nNeuns \nappeeiy \nwiu tag \nNen.. \ne paob. \naty'),
# ...
